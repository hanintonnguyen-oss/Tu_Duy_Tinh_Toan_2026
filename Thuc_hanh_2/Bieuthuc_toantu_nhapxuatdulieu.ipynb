# %%
# W2A1 : in chữ "Hello World!"
print("Hello World!")
# Out:
# Hello World!

# %%
# W2A2 : Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương ứng
name = input("Nhập tên của bạn : ")
print("Xin chào",name,"!")
# Out:
# Xin chào Nguyễn Hà Nin Tơn !

# %%
""" W2A3 : Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần 
nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập 
phân) theo định dạng đúng của output
"""
a,b = map(int,input("Nhập hai số nguyên a,b : ").split())
print("a + b = ",a+b)
print("a - b = ",a-b)
print("a * b = ",a*b)
print("a // b = ",a//b)
print("a % b = ",a%b)
print("a / b = ",round(a/b, 2))
# Out:
# a + b =  21
# a - b =  -1
# a * b =  110
# a // b =  0
# a % b =  10
# a / b =  0.91

# %%
""" W2A4 : Viết chương trình python để tính điểm trung bình môn học của một học sinh trong lớp. Có tổng cộng 
6 đầu điểm: a1, b1, c1, a2, b2, a3. Trong đó: 
• Các điểm a1, b1, c1 được nhân hệ số 1, 
• Các điểm a2, b2 được nhân hệ số 2, 
• Điểm a3 được nhân hệ số 3. 
Công thức tính điểm trung bình là: TB=((a1+b1+c1)+(a2+b2)×2+a3×3)/10 
Đầu vào: Trong bài tập này, dữ liệu vào chỉ gồm duy nhất một dòng bao gồm 6 số thể hiện cho 6 
đầu điểm a1, b1, c1, a2, b2, a3 theo đúng thứ tự đó. Trong đó, hai đầu điểm liên tiếp nhau sẽ được 
phân tách nhau bởi duy nhất 1 dấu cách. 
Đầu ra: Đầu ra là giá trị điểm trung bình môn học của 6 môn học, lấy đến 1 chữ số phần thập phân. 
"""
a1,b1,c1,a2,b2,a3 = map(float,input("Nhập vào 6 đầu điểm a1,b1,c1,a2,b2,a3 : ").split())
trung_binh = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print("Điểm trung bình môn học là: {:.1f}".format(trung_binh))
# Out:
# Điểm trung bình môn học là: 7.2

# %%
""" W2A5 : Trong bài này bạn hãy nhập vào hai số a, b 
(int) cách nhau một dấu cách, tính và in ra kết quả a mũ b.
"""
a,b = map(int,input("Nhập vào 2 số a,b : ").split())
print("a mũ b là : ",a**b)
# Out:
# a mũ b là :  64

# %%
""" W2A6 : Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí 
tự hoa tương ứng, in kí tự hoa này ra màn hình. 
"""
char = input("Nhập vào một kí tự chữ cái thường : ")
print("Mã Unicode của kí tự này là : ",ord(char))
print("Kí tự hoa tương ứng là : ",char.upper())
# Out:
# Mã Unicode của kí tự này là :  99
# Kí tự hoa tương ứng là :  C

# %%
""" W2A7 : Hãy in ra kết quả của hai biểu thức sau:  
A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5 
Chú ý: Hãy để ý phong cách viết mã của A 
"""
A = ((13**2)*3) + 5 
B = 13**2*3 + 5
print("Kết quả biểu thức A là : ",A)
print("Kết quả của biểu thức B là : ",B)
# Out:
# Kết quả biểu thức A là :  512
# Kết quả của biểu thức B là :  512

# %%
""" W2A8 : Fahrenheit, hay độ F, là một thang nhiệt độ được đặt theo tên nhà vật lý người Đức Daniel 
Gabriel Fahrenheit (1686–1736). Dựa vào nhiệt độ Celcius được nhập từ bàn phím, hãy 
chuyển sang độ F theo công thức: F = 9/5*C + 32 và in ra màn hình kết quả. Kết quả làm 
tròn đến hai chữ số thập phân đằng sau dấu phẩy.
"""
c = float(input("Nhập vào nhiệt độ Celcius : "))
f = (9/5) * c + 32
print("Nhiệt độ Fahrenheit là : ",round(f,2))
# Out:
# Nhiệt độ Fahrenheit là :  102.2

# %%
""" W2A9 : Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc 
đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về 
Việt Nam, Đạt phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển 
về Việt Nam, Đạt được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế 
VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Đạt phải trả để mua 
được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân. 
"""
x = float(input("Nhập vào giá của chiếc đồng hồ : "))
tong_tien = x + 10 + (x + 10)*0.3 + (x + 10)*0.1
print("Tổng số tiền Đạt phải trả là : ",round(tong_tien,2))
# Out:
# Tổng số tiền Đạt phải trả là :  84.0

# %%
""" W2A10 : Viết chương trình nhập vào tên 3 người từ bàn phím.  
In ra màn hình tên theo thứ tự đảo ngược
"""
names = input("Nhập tên 3 người cách nhau bởi dấu cách : ").split()
print("Tên theo thứ tự đảo ngược là : ", names[::-1])
# Out:
# Tên theo thứ tự đảo ngược là :  ['vu', 'huong', 'ton']

# %%
""" W2A11 : Viết chương trình chuyển từ giờ và phút sang giây  """
gio = float(input("Nhập vào số giờ : "))
phut = float(input("Nhập vào số phút : "))
print(gio,"=",gio*3600,"giây")
print(phut,"=",phut*60,"giây")
# Out:
# 4.0 = 14400.0 giây
# 50.0 = 3000.0 giây

# %%
""" W2A12 :  Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để 
bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán 
riêng lẻ. (Lưu ý: một khối rubic có 6 mặt) 
"""
n = int(input("Nhập vào độ dài cạnh của khối Rubik : "))
so_mieng_dan = 6*(n**2)
print("Số lượng miếng dán cần thiết là : ", so_mieng_dan)
# Out:
# Số lượng miếng dán cần thiết là :  150

# %%
""" W2A13 : Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị 
của phép tính tích giữa \a và \b. 
"""
a,b = map(int,input("Nhập vào 2 số nguyên dương a ,b : ").split())
print("Hàng đơn vị của a*b là : ",(a*b)%10)
# Out:
# Hàng đơn vị của a*b là :  0

# %%
""" W2A14 : Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/ 
hàm nào khác.  
"""
a = int(input("Nhập vào số a : "))
b = int(input("Nhập vào số B : "))
a = a+b
b = a-b
a = a-b
print("Sau khi hoán đổi : a=",a,"b=",b)
# Out:
# Sau khi hoán đổi : a= 8 b= 7

# %%
""" W2A16 : Để luyện tập, hãy viết vào ô dưới đây chương trình in ra trên màn hình tên các mùa trong 
năm bằng tiếng Anh. Mỗi mùa in trên một dòng, bắt đầu từ "Spring". 
"""
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
""" W2A17 : Yêu cầu: In ra màn hình tam giác có 3 dòng như sau: 
* 
*** 
*****
"""
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %%
""" W2A19 : Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng
"""
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
""" W2A20 : Viết chương trình in ra các tháng trong một năm bằng tiếng Anh. Mỗi tháng in trên một 
dòng, bắt đầu từ "January".
"""
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
""" W2A21 : Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần."""
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
